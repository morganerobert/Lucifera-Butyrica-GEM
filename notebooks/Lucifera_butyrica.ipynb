# %% [markdown]
# # **Draft reconstruction of Lucifera Butyrica**

# %% [markdown]
# ![Screenshot 2026-06-23 at 11.19.53.png](data:image/png;base64,...)

# %% [markdown]
# *   Downloaded the file as a .fasta. from ENA. Wanted to annotate it with RAST but I just created my account and it's not approved yet.
#
# *   Found Lucifera Butyrica's already annotated genome on NCBI. Downloaded : Genome sequences (FASTA), Sequence and annotation (GBFF), Protein (FASTA)
#
# *   Created a KBase account as it groups RAST and ModelSEED in one, it's a platform that groups the different tools I need for the draft reconstruction.
#
#
# *   Created a new narrative on KBase. Uploaded genomic.gbff file from the GCF File from NCBI. This file is aleady annotated and is the NCBI RefSeq curated version.
#
# *   Run it to obtain a genome object which is simply a more readable version of the genome that we need to use ModelSEED.
#
# *  Now using the app "Build Metabolic Model" - fba_tools v2.2.1 , which is a ModelSEED app used within the KBase platform
#
# *   Apparently the app is updated so I'm doing it again with "MS2 - Build Prokaryotic Metabolic Models with OMEGGA"

# %% [markdown]
# # **General characteristics**

# %% [markdown]
# **Build Metabolic Model (outdated)**
#
#
# *   285 reactions
# *   411 compounds
# *   69 genes
# *   2 gapfills
# *   Memote score : 93%
#
# **MS2 - Build Prokaryotic Metabolic Models with OMEGGA**
#
# *   364 reactions
# *   443 compounds
# *   5051 genes
# *   11 gapfills
# *   Memote score : 89%

# %% [markdown]
# # **MEMOTE score**

# %% [markdown]
# **Build metabolic model app (outdated one)** - ModelSEED

# %%
# !pip install memote

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c476502-9cfd-489e-9b9d-01fd72321336" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c476502-9cfd-489e-9b9d-01fd72321336">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !memote report snapshot \
    Lucifera_butyrica_model.xml \
    --filename Lucifera_MS1_memote.html
# Out:
# /usr/local/lib/python3.12/dist-packages/pandera/_pandas_deprecated.py:155: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...

# %%
files.download("Lucifera_MS1_memote.html")

# %% [markdown]
# Got an overall MEMOTE score of 93%.

# %% [markdown]
# **MS2 - Build Prokaryotic Metabolic Models with OMEGGA** - OMEGGA/ModelSEED2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-321aaf3b-3da1-43ba-a67d-3ee11f6e8683" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-321aaf3b-3da1-43ba-a67d-3ee11f6e8683">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !memote report snapshot \
    Lucifera_butyrica_MS2.xml \
    --filename Lucifera_MS2_memote.html
# Out:
# /usr/local/lib/python3.12/dist-packages/pandera/_pandas_deprecated.py:155: FutureWarning: Importing pandas-specific classes and functions from the
# top-level pandera module will be **removed in a future version of pandera**.
# If you're using pandera to validate pandas objects, we highly recommend updating
# your import:
#
# ```
# # old import
# import pandera as pa
#
# # new import
# import pandera.pandas as pa
# ```
#
# If you're using pandera to validate objects from other compatible libraries
# like pyspark or polars, see the supported libraries section of the documentation
# for more information on how to import pandera:
#
# https://pandera.readthedocs.io/en/stable/supported_libraries.html
#
# To disable this warning, set the environment variable:
#
# ```
# export DISABLE_PANDERA_IMPORT_WARNING=True
# ```
#
#   warnings.warn(_future_warning, FutureWarning)
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ...

# %%
from google.colab import files
files.download("Lucifera_MS2_memote.html")

# %% [markdown]
# Got an overall MEMOTE score of 89%.
